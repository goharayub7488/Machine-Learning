# %%
pip install requests beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
URL ="https://www.timeanddate.com/weather/?low=c"
webPage=requests.get(URL).text

# %%
from decorator import append
soup=BeautifulSoup(webPage,'lxml')
cities=soup.find_all('tr')
name=[]
dayTime=[]
temperature=[]
for i in cities:
  links=i.find_all('a')
  for link in links:
    name.append(link.text)
  DayTimeCell=i.find_all('td',class_='r')
  for day in DayTimeCell:
    if day.text=="":
      continue
    else:
      dayTime.append(day.text)
  temp=i.find_all('td',class_='rbi')
  for t in temp:
    temperature.append(t.text)

# %%
print(len(name))
print(len(dayTime))
print(len(temperature))
# Out:
# 181
# 181
# 181

# %%
d={'Cities':name,'DayTime':dayTime,'Temperature':temperature}
df=pd.DataFrame(d)
df
# Out:
#           Cities    DayTime Temperature
# 0          Accra  Thu 01:27       27 °C
# 1         Manila  Thu 09:27       26 °C
# 2    Addis Ababa  Thu 04:27       22 °C
# 3         Maputo  Thu 03:27       25 °C
# 4        Algiers  Thu 02:27       15 °C
# ..           ...        ...         ...
# 176         Male  Thu 06:27       28 °C
# 177      Yaoundé  Thu 02:27       23 °C
# 178      Managua  Wed 19:27       31 °C
# 179       Zagreb  Thu 02:27        7 °C
# 180       Manama  Thu 04:27       21 °C
#
# [181 rows x 3 columns]

# %%
df = df.sort_values(by='Cities').reset_index(drop=True)

# %%
df[df['Cities']=='Islamabad']
# Out:
#        Cities    DayTime Temperature
# 65  Islamabad  Thu 06:27       16 °C

# %%
df = df.to_csv("data/file.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df = df.to_csv("data/file.csv",index=False)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
